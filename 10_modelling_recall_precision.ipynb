# %%
# %run 05_functions_for_modelling.ipynb

# %%
df = pd.read_csv('hsls_clean.csv')

with open('train_test_split.json') as f:
    split = json.load(f)

with open('feature_tiers.json') as f:
    feature_tiers = json.load(f)

train_idx = split['train']
test_idx  = split['test']

# %%
df = pd.read_csv('hsls_clean_trad.csv')

with open('train_test_split.json') as f:
    split = json.load(f)

with open('feature_tiers.json') as f:
    feature_tiers = json.load(f)

train_idx = split['train']
test_idx  = split['test']

# %% [markdown]
# # Trad / Precision

# %%
tier1_search_precision_trad, X_train_tier1_trad, y_train_tier1_trad, X_test_tier1_trad, y_test_tier1_trad = fit_models(
    features=feature_tiers['tier1'], df=df, train_idx=train_idx, test_idx=test_idx, 
    target='X4EVERDROP_TRAD', refit='precision')

print("Best params:", tier1_search_precision_trad.best_params_)
print("Best CV Precision:", round(tier1_search_precision_trad.best_score_, 4))
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Best params: {'subsample': 1.0, 'n_estimators': 1000, 'max_depth': 15, 'learning_rate': 0.005, 'colsample_bytree': 0.5}
# Best CV Precision: 0.5786

# %%
fine_grid_tier1_precision_trad = define_fine_grid(tier1_search_precision_trad.cv_results_, metric='precision')
tier1_fine_search_precision_trad = fit_fine_search(fine_grid_tier1_precision_trad, X_train_tier1_trad, y_train_tier1_trad, refit='precision')
# Out:
# Metric: precision
# Score range: 0.2437 — 0.5786
# Threshold: 0.5116 (21 combinations above threshold)
#
#     mean_test_precision  std_test_precision  param_n_estimators  param_max_depth  param_learning_rate  param_subsample  param_colsample_bytree
# 91             0.578619            0.026321                1000               15                0.005              1.0                     0.5
# 0              0.571125            0.031026                 200               15                0.050              0.9                     0.7
# 66             0.567849            0.032133                 500               15                0.010              0.6                     0.5
# 9              0.563750            0.036826                1000               15                0.200              1.0                     0.5
# 49             0.559290            0.041982                1000               15                0.010              0.6                     0.8
# 2              0.559107            0.025336                 750               15                0.010              0.7                     0.8
# 28             0.555112            0.040600                 750               15                0.100              0.8                     0.8
# 58             0.553094            0.025397                 500               10                0.100              0.9                     0.6
# 67             0.542575            0.039108                 100               15                0.100              0.7                     0.6
# 29             0.542438            0.040953                 750               10                0.100              1.0                     0.6
# 73             0.540787            0.040498                1000               10                0.100              0.8                     0.6
# 99             0.538956            0.034685                 750               10                0.050              0.7                     0.9
# 97             0.531663            0.028484                1000                8                0.050              0.9                     1.0
# 79             0.530133            0.038049                 200               10                0.100              0.9                     0.8
# 41             0.524659            0.033967                 200               10                0.200              0.9                     0.7
# 59             0.522336            0.021866                1000                8                0.050              0.9                     0.9
# 61             0.521526            0.030683                 750               15                0.005              0.6                     0.9
# 64             0.517518            0.045597                 200               15                0.010              0.6                     0.7
# 39             0.515587            0.027742                 750                8                0.050              0.9                     0.9
# 32             0.515077            0.048181                 200               10                0.200              0.6                     0.6
# 72             0.511970            0.042837                 750                8                0.200              1.0                     0.7
#
# param_n_estimators
# 750     7
# 1000    6
# 200     5
# 500     2
# 100     1
# Name: count, dtype: int64
#
# param_max_depth
# 15    10
# 10     7
# 8      4
# Name: count, dtype: int64
#
# param_learning_rate
# 0.100    6
# 0.050    5
# 0.010    4
# 0.200    4
# 0.005    2
# Name: count, dtype: int64
#
# param_subsample
# 0.9    7
# 0.6    5
# 1.0    4
# 0.7    3
# 0.8    2
# Name: count, dtype: int64
#
# param_colsample_bytree
# 0.6    5
# 0.7    4
# 0.8    4
# 0.9    4
# 0.5    3
# 1.0    1
# Name: count, dtype: int64
#
# n_estimators: [200, np.int64(300), np.int64(500), 750, 1000]
# max_depth: [8, 10, 15]
# learning_rate: [0.01, 0.05, 0.1, 0.2]
# subsample: [0.6, np.float64(0.7), np.float64(0.8), 0.9, 1.0]
# colsample_bytree: [0.6, 0.7, 0.8, 0.9]
#
# Total combinations: 1200
# Total fits (x5 folds): 6000
# Fitting 5 folds for each of 1200 candidates, totalling 6000 fits
